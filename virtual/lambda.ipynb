# %% [markdown]
# ## lambda.py
# ##### 람다 함수에 대한 예제 프로그램입니다.

# %%
(lambda x,y : x+y)(10, 20)
# Out:
# 30

# %%
add = lambda x, y: x+y

print(type(add))
print(add(1,2))
# Out:
# <class 'function'>
# 3
